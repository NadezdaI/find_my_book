# %%
from bg_parser import extract_product, save_csv

# %%
url = "https://www.biblio-globus.ru/product/11061311"
row = extract_product(url)

if row is None:
    print("❌ Пропущено (не книга):", url)
else:
    print("Parsed:", {k: (str(v)[:120] + ("…" if isinstance(v, str) and len(v) > 120 else "")) for k, v in row.items()})
    save_csv(row, append=True)
    print("✅ Saved to books.csv")
# Out:
# Parsed: {'page_url': 'https://www.biblio-globus.ru/product/11061311', 'image_url': 'https://static1.bgshop.ru/imagehandler.ashx?filename=11061311.jpg&width=550', 'author': 'Лупенко П.А.', 'title': 'Депрессия: выход есть. Возможно, самая радостная книга в твоей жизни', 'annotation': 'Только тот, кто прошёл через ад депрессии, по-настоящему понимает, как выбраться из него. Пётр Лупенко — коуч по самораз…'}
# ✅ Saved to books.csv

# %%
# collect_from_catalog_new.py
# Требует: requests, beautifulsoup4, lxml, pandas
import time
import re
import os
import requests
import pandas as pd
from bs4 import BeautifulSoup
from urllib.parse import urlparse, parse_qs, urlencode, urlunparse

# --- хедера как у браузера ---
HEADERS = {
    "User-Agent": ("Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                   "AppleWebKit/537.36 (KHTML, like Gecko) "
                   "Chrome/120.0.0.0 Safari/537.36"),
    "Accept-Language": "ru-RU,ru;q=0.9,en-US;q=0.8",
    "Referer": "https://www.biblio-globus.ru/",
}

# быстрая загрузка страницы каталога
def get_soup(url: str) -> BeautifulSoup:
    r = requests.get(url, headers=HEADERS, timeout=20)
    r.raise_for_status()
    return BeautifulSoup(r.text, "lxml")

# меняем только параметр ?page= в URL каталога
def set_page_param(category_url: str, page_num: int) -> str:
    parts = urlparse(category_url)
    q = parse_qs(parts.query)
    q["page"] = [str(page_num)]
    new_query = urlencode(q, doseq=True)
    return urlunparse(parts._replace(query=new_query))

# достаём все product-id с одной страницы каталога
def extract_product_ids_from_catalog_soup(soup: BeautifulSoup) -> list[int]:
    ids = set()
    # 1) быстрый и надёжный вариант: ищем все ссылки на /product/<id>
    for a in soup.find_all("a", href=True):
        href = a["href"]
        if "/product/" in href:
            pid = href.split("/product/")[1].split("?")[0].strip("/")
            if pid.isdigit():
                ids.add(int(pid))
    # 2) иногда ссылки лежат в data-атрибутах — можно продублировать regex по всему HTML
    if not ids:
        html = soup.decode()
        for pid in re.findall(r'/product/(\d+)', html):
            ids.add(int(pid))
    return sorted(ids)

# основной сборщик: идём по page=1..N, пока приходят новые id
def collect_product_urls_from_catalog(category_url: str,
                                      start_page: int = 1,
                                      max_pages: int = 1000,
                                      sleep: float = 0.4,
                                      empty_streak_break: int = 2) -> list[str]:
    seen, urls = set(), []
    empty_streak = 0
    for page in range(start_page, start_page + max_pages):
        page_url = set_page_param(category_url, page)
        try:
            soup = get_soup(page_url)
        except Exception as e:
            print(f"[page={page}] ❌ ошибка загрузки: {e}")
            break

        page_ids = extract_product_ids_from_catalog_soup(soup)
        new_ids = [pid for pid in page_ids if pid not in seen]

        if not new_ids:
            empty_streak += 1
            print(f"[page={page}] 0 новых ID (подряд {empty_streak})")
            if empty_streak >= empty_streak_break:
                break
        else:
            empty_streak = 0
            for pid in new_ids:
                seen.add(pid)
                urls.append(f"https://www.biblio-globus.ru/product/{pid}")
            print(f"[page={page}] +{len(new_ids)} новых (всего {len(urls)})")

        time.sleep(sleep)

    return urls

# ---- подключаем твой модуль парсинга карточек ----
from bg_parser import extract_product, save_csv  # уже сделали ранее

def run_catalog_to_csv(category_url: str,
                       csv_path: str = "books.csv",
                       append: bool = False,
                       max_pages: int = 1000,
                       target_rows: int | None = None):
    product_urls = collect_product_urls_from_catalog(
        category_url, start_page=1, max_pages=max_pages, sleep=0.2
    )
    print(f"🥳 Собрано ссылок: {len(product_urls)}. Начинаю парсинг карточек…")

    rows, kept = [], 0
    for i, url in enumerate(product_urls, 1):
        try:
            row = extract_product(url)  # вернёт dict или None (если не книга/аудио)
            if row is None:
                if i % 50 == 0:
                    print(f"{i:04d}. ⏭️ пропущено (не книга/аудио) {url}")
                continue
            rows.append(row)
            kept += 1
            # периодически сохраняем, чтобы не потерять прогресс
            if len(rows) >= 50:
                save_csv(rows, path=csv_path, append=append)
                append = True
                rows.clear()
                print(f"💾 промежуточно сохранено, всего книг: {kept}")
            if target_rows and kept >= target_rows:
                break
        except Exception as e:
            print(f"{i:04d}. ❌ ошибка парсинга {url}: {e}")

        time.sleep(0.2)  # вежливая задержка

    if rows:
        save_csv(rows, path=csv_path, append=append)

    print(f"🎉 Готово: сохранено книг {kept} → {csv_path}")

# ======== пример запуска ========
# if __name__ == "__main__":
#     CATEGORY = "https://www.biblio-globus.ru/catalog/category?id=226&page=1&sort=0&instock=&isdiscount="
#     run_catalog_to_csv(CATEGORY, csv_path="books.csv", append=False, max_pages=1000, target_rows=5000)

# %% [markdown]
# https://www.biblio-globus.ru/product/11061311

# %%
CATEGORY = "https://www.biblio-globus.ru/catalog/category?id=226&page=1&sort=0&instock=&isdiscount="
run_catalog_to_csv(CATEGORY, csv_path="books.csv", append=False, max_pages=1000, target_rows=5000)
# Out:
# [page=1] +12 новых (всего 12)
# [page=2] +12 новых (всего 24)
# [page=3] +12 новых (всего 36)
# [page=4] +12 новых (всего 48)
# [page=5] +12 новых (всего 60)
# [page=6] +12 новых (всего 72)
# [page=7] +12 новых (всего 84)
# [page=8] +12 новых (всего 96)
# [page=9] +12 новых (всего 108)
# [page=10] +12 новых (всего 120)
# [page=11] +12 новых (всего 132)
# [page=12] +12 новых (всего 144)
# [page=13] +12 новых (всего 156)
# [page=14] +12 новых (всего 168)
# [page=15] +12 новых (всего 180)
# [page=16] +12 новых (всего 192)
# [page=17] +12 новых (всего 204)
# [page=18] +12 новых (всего 216)
# [page=19] +12 новых (всего 228)
# [page=20] +12 новых (всего 240)
# [page=21] +12 новых (всего 252)
# [page=22] +12 новых (всего 264)
# [page=23] +12 новых (всего 276)
# [page=24] +12 новых (всего 288)
# [page=25] +12 новых (всего 300)
# [page=26] +12 новых (всего 312)
# [page=27] +12 новых (всего 324)
# [page=28] +12 новых (всего 336)
# [page=29] +12 новых (всего 348)
# [page=30] +12 новых (всего 360)
# [page=31] +12 новых (всего 372)
# [page=32] +12 новых (всего 384)
# [page=33] +12 новых (всего 396)
# [page=34] +12 новых (всего 408)
# [page=35] +12 новых (всего 420)
# [page=36] +12 новых (всего 432)
# [page=37] +12 новых (всего 444)
# [page=38] +12 новых (всего 456)
# [page=39] +12 новых (всего 468)
# [page=40] +12 новых (всего 480)
# [page=41] +12 новых (всего 492)
# [page=42] +12 новых (всего 504)
# [page=43] +12 новых (всего 516)
# [page=44] +12 новых (всего 528)
# [page=45] +12 новых (всего 540)
# [page=46] +12 новых (всего 552)
# [page=47] +12 новых (всего 564)
# [page=48] +12 новых (всего 576)
# [page=49] +12 новых (всего 588)
# [page=50] +12 новых (всего 600)
# [page=51] +12 новых (всего 612)
# [page=52] +12 новых (всего 624)
# [page=53] +12 новых (всего 636)
# [page=54] +12 новых (всего 648)
# [page=55] +12 новых (всего 660)
# [page=56] +12 новых (всего 672)
# [page=57] +12 новых (всего 684)
# [page=58] +12 новых (всего 696)
# [page=59] +12 новых (всего 708)
# [page=60] +12 новых (всего 720)
# [page=61] +12 новых (всего 732)
# [page=62] +12 новых (всего 744)
# [page=63] +12 новых (всего 756)
# [page=64] +12 новых (всего 768)
# [page=65] +12 новых (всего 780)
# [page=66] +12 новых (всего 792)
# [page=67] +12 новых (всего 804)
# [page=68] +12 новых (всего 816)
# [page=69] +12 новых (всего 828)
# [page=70] +12 новых (всего 840)
# [page=71] +12 новых (всего 852)
# [page=72] +12 новых (всего 864)
# [page=73] +12 новых (всего 876)
# [page=74] +12 новых (всего 888)
# [page=75] +12 новых (всего 900)
# [page=76] +12 новых (всего 912)
# [page=77] +12 новых (всего 924)
# [page=78] +12 новых (всего 936)
# [page=79] +12 новых (всего 948)
# [page=80] +12 новых (всего 960)
# [page=81] +12 новых (всего 972)
# [page=82] +12 новых (всего 984)
# [page=83] +12 новых (всего 996)
# [page=84] +12 новых (всего 1008)
# [page=85] +12 новых (всего 1020)
# [page=86] +12 новых (всего 1032)
# [page=87] +12 новых (всего 1044)
# [page=88] +12 новых (всего 1056)
# [page=89] +12 новых (всего 1068)
# [page=90] +12 новых (всего 1080)
# [page=91] +12 новых (всего 1092)
# [page=92] +12 новых (всего 1104)
# [page=93] +12 новых (всего 1116)
# [page=94] +12 новых (всего 1128)
# [page=95] +12 новых (всего 1140)
# [page=96] +12 новых (всего 1152)
# [page=97] +12 новых (всего 1164)
# [page=98] +12 новых (всего 1176)
# [page=99] +12 новых (всего 1188)
# [page=100] +12 новых (всего 1200)
# [page=101] +12 новых (всего 1212)
# [page=102] +12 новых (всего 1224)
# [page=103] +12 новых (всего 1236)
# [page=104] +12 новых (всего 1248)
# [page=105] +12 новых (всего 1260)
# [page=106] +12 новых (всего 1272)
# [page=107] +12 новых (всего 1284)
# [page=108] +12 новых (всего 1296)
# [page=109] +12 новых (всего 1308)
# [page=110] +12 новых (всего 1320)
# [page=111] +12 новых (всего 1332)
# [page=112] +12 новых (всего 1344)
# [page=113] +12 новых (всего 1356)
# [page=114] +12 новых (всего 1368)
# [page=115] +12 новых (всего 1380)
# [page=116] +12 новых (всего 1392)
# [page=117] +12 новых (всего 1404)
# [page=118] +12 новых (всего 1416)
# [page=119] +12 новых (всего 1428)
# [page=120] +12 новых (всего 1440)
# [page=121] +12 новых (всего 1452)
# [page=122] +12 новых (всего 1464)
# [page=123] +12 новых (всего 1476)
# [page=124] +12 новых (всего 1488)
# [page=125] +12 новых (всего 1500)
# [page=126] +12 новых (всего 1512)
# [page=127] +12 новых (всего 1524)
# [page=128] +12 новых (всего 1536)
# [page=129] +12 новых (всего 1548)
# [page=130] +12 новых (всего 1560)
# [page=131] +12 новых (всего 1572)
# [page=132] +12 новых (всего 1584)
# [page=133] +12 новых (всего 1596)
# [page=134] +12 новых (всего 1608)
# [page=135] +12 новых (всего 1620)
# [page=136] +12 новых (всего 1632)
# [page=137] +12 новых (всего 1644)
# [page=138] +12 новых (всего 1656)
# [page=139] +12 новых (всего 1668)
# [page=140] +12 новых (всего 1680)
# [page=141] +12 новых (всего 1692)
# [page=142] +12 новых (всего 1704)
# [page=143] +12 новых (всего 1716)
# [page=144] +12 новых (всего 1728)
# [page=145] +12 новых (всего 1740)
# [page=146] +12 новых (всего 1752)
# [page=147] +12 новых (всего 1764)
# [page=148] +12 новых (всего 1776)
# [page=149] +12 новых (всего 1788)
# [page=150] +12 новых (всего 1800)
# [page=151] +12 новых (всего 1812)
# [page=152] +12 новых (всего 1824)
# [page=153] +12 новых (всего 1836)
# [page=154] +12 новых (всего 1848)
# [page=155] +12 новых (всего 1860)
# [page=156] +12 новых (всего 1872)
# [page=157] +12 новых (всего 1884)
# [page=158] +12 новых (всего 1896)
# [page=159] +12 новых (всего 1908)
# [page=160] +12 новых (всего 1920)
# [page=161] +12 новых (всего 1932)
# [page=162] +12 новых (всего 1944)
# [page=163] +12 новых (всего 1956)
# [page=164] +12 новых (всего 1968)
# [page=165] +12 новых (всего 1980)
# [page=166] +12 новых (всего 1992)
# [page=167] +12 новых (всего 2004)
# [page=168] +12 новых (всего 2016)
# [page=169] +12 новых (всего 2028)
# [page=170] +12 новых (всего 2040)
# [page=171] +12 новых (всего 2052)
# [page=172] +12 новых (всего 2064)
# [page=173] +12 новых (всего 2076)
# [page=174] +12 новых (всего 2088)
# [page=175] +12 новых (всего 2100)
# [page=176] +12 новых (всего 2112)
# [page=177] +12 новых (всего 2124)
# [page=178] +12 новых (всего 2136)
# [page=179] +12 новых (всего 2148)
# [page=180] +12 новых (всего 2160)
# [page=181] +12 новых (всего 2172)
# [page=182] +12 новых (всего 2184)
# [page=183] +12 новых (всего 2196)
# [page=184] +12 новых (всего 2208)
# [page=185] +12 новых (всего 2220)
# [page=186] +12 новых (всего 2232)
# [page=187] +12 новых (всего 2244)
# [page=188] +12 новых (всего 2256)
# [page=189] +12 новых (всего 2268)
# [page=190] +12 новых (всего 2280)
# [page=191] +12 новых (всего 2292)
# [page=192] +12 новых (всего 2304)
# [page=193] +12 новых (всего 2316)
# [page=194] +12 новых (всего 2328)
# [page=195] +12 новых (всего 2340)
# [page=196] +12 новых (всего 2352)
# [page=197] +12 новых (всего 2364)
# [page=198] +12 новых (всего 2376)
# [page=199] +12 новых (всего 2388)
# [page=200] +12 новых (всего 2400)
# [page=201] +12 новых (всего 2412)
# [page=202] +12 новых (всего 2424)
# [page=203] +12 новых (всего 2436)
# [page=204] +12 новых (всего 2448)
# [page=205] +12 новых (всего 2460)
# [page=206] +12 новых (всего 2472)
# [page=207] +12 новых (всего 2484)
# [page=208] +12 новых (всего 2496)
# [page=209] +12 новых (всего 2508)
# [page=210] +12 новых (всего 2520)
# [page=211] +12 новых (всего 2532)
# [page=212] +12 новых (всего 2544)
# [page=213] +12 новых (всего 2556)
# [page=214] +12 новых (всего 2568)
# [page=215] +12 новых (всего 2580)
# [page=216] +12 новых (всего 2592)
# [page=217] +12 новых (всего 2604)
# [page=218] +12 новых (всего 2616)
# [page=219] +12 новых (всего 2628)
# [page=220] +12 новых (всего 2640)
# [page=221] +12 новых (всего 2652)
# [page=222] +12 новых (всего 2664)
# [page=223] +12 новых (всего 2676)
# [page=224] +12 новых (всего 2688)
# [page=225] +12 новых (всего 2700)
# [page=226] +12 новых (всего 2712)
# [page=227] +12 новых (всего 2724)
# [page=228] +12 новых (всего 2736)
# [page=229] +12 новых (всего 2748)
# [page=230] +12 новых (всего 2760)
# [page=231] +12 новых (всего 2772)
# [page=232] +12 новых (всего 2784)
# [page=233] +12 новых (всего 2796)
# [page=234] +12 новых (всего 2808)
# [page=235] +12 новых (всего 2820)
# [page=236] +12 новых (всего 2832)
# [page=237] +12 новых (всего 2844)
# [page=238] +12 новых (всего 2856)
# [page=239] +12 новых (всего 2868)
# [page=240] 0 новых ID (подряд 1)
# [page=241] 0 новых ID (подряд 2)
# 🥳 Собрано ссылок: 2868. Начинаю парсинг карточек…
# 0007. ❌ ошибка парсинга https://www.biblio-globus.ru/product/11024372: ('Connection aborted.', ConnectionResetError(10054, 'Удаленный хост принудительно разорвал существующее подключение', None, 10054, None))
# 💾 промежуточно сохранено, всего книг: 50
# 💾 промежуточно сохранено, всего книг: 100
# 💾 промежуточно сохранено, всего книг: 150
# 💾 промежуточно сохранено, всего книг: 200
# 0250. ⏭️ пропущено (не книга/аудио) https://www.biblio-globus.ru/product/10982708
# 💾 промежуточно сохранено, всего книг: 250
# 💾 промежуточно сохранено, всего книг: 300
# 💾 промежуточно сохранено, всего книг: 350
# 💾 промежуточно сохранено, всего книг: 400
# 💾 промежуточно сохранено, всего книг: 450
# 💾 промежуточно сохранено, всего книг: 500
# 0550. ⏭️ пропущено (не книга/аудио) https://www.biblio-globus.ru/product/11044745
# 💾 промежуточно сохранено, всего книг: 550
# 💾 промежуточно сохранено, всего книг: 600
# 💾 промежуточно сохранено, всего книг: 650
# 💾 промежуточно сохранено, всего книг: 700
# 💾 промежуточно сохранено, всего книг: 750
# 💾 промежуточно сохранено, всего книг: 800
# 💾 промежуточно сохранено, всего книг: 850
# 💾 промежуточно сохранено, всего книг: 900
# 💾 промежуточно сохранено, всего книг: 950
# 💾 промежуточно сохранено, всего книг: 1000
# 💾 промежуточно сохранено, всего книг: 1050
# 💾 промежуточно сохранено, всего книг: 1100
# 💾 промежуточно сохранено, всего книг: 1150
# 💾 промежуточно сохранено, всего книг: 1200
# 1347. ❌ ошибка парсинга https://www.biblio-globus.ru/product/10706414: ('Connection aborted.', ConnectionResetError(10054, 'Удаленный хост принудительно разорвал существующее подключение', None, 10054, None))
# 💾 промежуточно сохранено, всего книг: 1250
# 💾 промежуточно сохранено, всего книг: 1300
# 💾 промежуточно сохранено, всего книг: 1350
# 1500. ⏭️ пропущено (не книга/аудио) https://www.biblio-globus.ru/product/10433929
# 💾 промежуточно сохранено, всего книг: 1400
# 💾 промежуточно сохранено, всего книг: 1450
# 1600. ⏭️ пропущено (не книга/аудио) https://www.biblio-globus.ru/product/11049910
# 💾 промежуточно сохранено, всего книг: 1500
# 💾 промежуточно сохранено, всего книг: 1550
# 💾 промежуточно сохранено, всего книг: 1600
# 💾 промежуточно сохранено, всего книг: 1650
# 💾 промежуточно сохранено, всего книг: 1700
# 1950. ⏭️ пропущено (не книга/аудио) https://www.biblio-globus.ru/product/10938661
# 💾 промежуточно сохранено, всего книг: 1750
# 💾 промежуточно сохранено, всего книг: 1800
# 💾 промежуточно сохранено, всего книг: 1850
# 💾 промежуточно сохранено, всего книг: 1900
# 2150. ⏭️ пропущено (не книга/аудио) https://www.biblio-globus.ru/product/11031810
# 💾 промежуточно сохранено, всего книг: 1950
# 2200. ⏭️ пропущено (не книга/аудио) https://www.biblio-globus.ru/product/11016468
# 💾 промежуточно сохранено, всего книг: 2000
# 💾 промежуточно сохранено, всего книг: 2050
# 💾 промежуточно сохранено, всего книг: 2100
# 💾 промежуточно сохранено, всего книг: 2150
# 💾 промежуточно сохранено, всего книг: 2200
# 💾 промежуточно сохранено, всего книг: 2250
# 💾 промежуточно сохранено, всего книг: 2300
# 💾 промежуточно сохранено, всего книг: 2350
# 💾 промежуточно сохранено, всего книг: 2400
# 💾 промежуточно сохранено, всего книг: 2450
# 💾 промежуточно сохранено, всего книг: 2500
# 💾 промежуточно сохранено, всего книг: 2550
# 🎉 Готово: сохранено книг 2557 → books.csv
